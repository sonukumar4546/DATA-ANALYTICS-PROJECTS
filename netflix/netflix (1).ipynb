# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📘 Netflix Titles Dataset — Description
#
# This dataset contains **7,770 records** of Movies and TV Shows available on Netflix.
# It is ideal for **EDA**, **content analysis**, **recommendation systems**, and **trend exploration**.
#
# ---
#
# ## 📂 Dataset Overview
#
# | Property | Value |
# |---------|--------|
# | **Rows** | 7,770 |
# | **Columns** | 15 |
# | **File Name** | `netflic.csv` |
#
# ---
#
# ## 🧾 Column Description
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **Unnamed: 0**  | Index column created during export (can be dropped). |
# | **show_id**     | Unique ID for each Netflix title. |
# | **type**        | Type of content — *Movie* or *TV Show*. |
# | **title**       | Name of the content. |
# | **director**    | Director(s) of the film/show. |
# | **cast**        | Lead acto

# %%
# !git clone 'https://github.com/HarshvardhanSingh-13/Datasets'
# Out:
# Cloning into 'Datasets'...
# remote: Enumerating objects: 335, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 335 (delta 22), reused 0 (delta 0), pack-reused 242 (from 1)
# Receiving objects: 100% (335/335), 302.68 MiB | 14.48 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# Updating files: 100% (243/243), done.

# %%
import pandas as pd
import numpy as nm

# %%
df=pd.read_csv('/content/Datasets/Netflix_Titles Dataset/netflix_titles.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head(40)
# Out:
#    show_id     type                                title  \
# 0       s1  TV Show                                   3%
# 1       s2    Movie                                 7:19
# 2       s3    Movie                                23:59
# 3       s4    Movie                                    9
# 4       s5    Movie                                   21
# 5       s6  TV Show                                   46
# 6       s7    Movie                                  122
# 7       s8    Movie                                  187
# 8       s9    Movie                                  706
# 9      s10    Movie                                 1920
# 10     s11    Movie                                 1922
# 11     s12  TV Show                                 1983
# 12     s13  TV Show                                 1994
# 13     s14    Movie                                2,215
# 14     s15    Movie                                 3022
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
df = df.dropna(subset=['date_added'])

# %%
df['cast'].nunique()
# Out:
# 6821

# %%
df['date_added']
# Out:
# 0          August 14, 2020
# 1        December 23, 2016
# 2        December 20, 2018
# 3        November 16, 2017
# 4          January 1, 2020
#                ...
# 7782      October 19, 2020
# 7783         March 2, 2019
# 7784    September 25, 2020
# 7785      October 31, 2020
# 7786         March 1, 2020
# Name: date_added, Length: 7777, dtype: object

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2379
# cast             718
# country          506
# date_added         0
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df['added_year']=df['date_added'].str.split(',').str[1].astype(int)
# Out:
# /tmp/ipython-input-4277552638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['added_year']=df['date_added'].str.split(',').str[1].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7777 entries, 0 to 7786
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7777 non-null   object
#  1   type          7777 non-null   object
#  2   title         7777 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7059 non-null   object
#  5   country       7271 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7777 non-null   int64
#  8   rating        7770 non-null   object
#  9   duration      7777 non-null   object
#  10  listed_in     7777 non-null   object
#  11  description   7777 non-null   object
#  12  added_year    7777 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 850.6+ KB

# %%
df['added_month']=df['date_added'].str.split(',').str[0].str.split(' ').str[0]
# Out:
# /tmp/ipython-input-1760867088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['added_month']=df['date_added'].str.split(',').str[0].str.split(' ').str[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7777 entries, 0 to 7786
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7777 non-null   object
#  1   type          7777 non-null   object
#  2   title         7777 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7059 non-null   object
#  5   country       7271 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7777 non-null   int64
#  8   rating        7770 non-null   object
#  9   duration      7777 non-null   object
#  10  listed_in     7777 non-null   object
#  11  description   7777 non-null   object
#  12  added_year    7777 non-null   int64
#  13  added_month   7777 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 911.4+ KB

# %%
df.tail(50)
# Out:
#      show_id     type                                        title  \
# 7737   s7738    Movie                                  Young Tiger
# 7738   s7739  TV Show                              Young Wallander
# 7739   s7740    Movie                              Your Excellency
# 7740   s7741  TV Show                            Your lie in April
# 7741   s7742    Movie                    Your Name Engraved Herein
# 7742   s7743    Movie                                     Your Son
# 7743   s7744  TV Show                              Yours Fatefully
# 7744   s7745    Movie                  Yours Sincerely, Kanan Gill
# 7745   s7746    Movie                         Yours, Mine and Ours
# 7746   s7747  TV Show                                 دفعة القاهرة
# 7747   s7748    Movie                                       اشتباك
# 7748   s7749    Movie                                    الف مبروك
# 7749   s7750  TV Show                                    Yu-Gi-Oh!
# ...

# %%
df['country'].value_counts()
# Out:
# country
# United States                                     2549
# India                                              923
# United Kingdom                                     396
# Japan                                              225
# South Korea                                        183
#                                                   ...
# Germany, United States, United Kingdom, Canada       1
# Peru, United States, United Kingdom                  1
# Saudi Arabia, United Arab Emirates                   1
# United Kingdom, France, United States, Belgium       1
# France, Norway, Lebanon, Belgium                     1
# Name: count, Length: 681, dtype: int64

# %%
import sqlite3

# Create an in-memory SQLite database
conn = sqlite3.connect(':memory:')

# Write the DataFrame to a SQL table named 'netflix_titles'
df.to_sql('netflix_titles', conn, index=False, if_exists='replace')

# Example of running a query
query = "SELECT * FROM netflix_titles"
result = pd.read_sql_query(query, conn)
print(result)

# Close the connection
conn.close()
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7772   s7783    Movie                                     Zozo
# 7773   s7784    Movie                                   Zubaan
# 7774   s7785    Movie                        Zulu Man in Japan
# 7775   s7786  TV Show                    Zumbo's Just Desserts
# 7776   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                  None  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7777 entries, 0 to 7786
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7777 non-null   object
#  1   type          7777 non-null   object
#  2   title         7777 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7059 non-null   object
#  5   country       7271 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7777 non-null   int64
#  8   rating        7770 non-null   object
#  9   duration      7777 non-null   object
#  10  listed_in     7777 non-null   object
#  11  description   7777 non-null   object
#  12  added_year    7777 non-null   int64
#  13  added_month   7777 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 911.4+ KB

# %%
# 2. Handle missing 'country'
# We'll fill with the mode, which is the most common country.
mode_country = df['country'].mode()[0]
df['country'] = df['country'].fillna(mode_country)
# Out:
# /tmp/ipython-input-3383548616.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = df['country'].fillna(mode_country)

# %%
# 3. Drop the few rows with missing 'date_added' and 'rating'
# Since the number is small (less than 0.2% of data), dropping them is a safe option.
df.dropna(subset=['date_added', 'rating'], inplace=True)
# Out:
# /tmp/ipython-input-1246855709.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['date_added', 'rating'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7770 entries, 0 to 7786
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7770 non-null   object
#  1   type          7770 non-null   object
#  2   title         7770 non-null   object
#  3   director      5394 non-null   object
#  4   cast          7052 non-null   object
#  5   country       7770 non-null   object
#  6   date_added    7770 non-null   object
#  7   release_year  7770 non-null   int64
#  8   rating        7770 non-null   object
#  9   duration      7770 non-null   object
#  10  listed_in     7770 non-null   object
#  11  description   7770 non-null   object
#  12  added_year    7770 non-null   int64
#  13  added_month   7770 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 910.5+ KB

# %%
# 1. Handle missing values in 'director' and 'cast'
# Since these are text fields and many are missing, we'll fill them with 'Unknown'.
df['director'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Unknown')
# Out:
# /tmp/ipython-input-1474305360.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['director'] = df['director'].fillna('Unknown')
# /tmp/ipython-input-1474305360.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cast'] = df['cast'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7770 entries, 0 to 7786
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7770 non-null   object
#  1   type          7770 non-null   object
#  2   title         7770 non-null   object
#  3   director      7770 non-null   object
#  4   cast          7770 non-null   object
#  5   country       7770 non-null   object
#  6   date_added    7770 non-null   object
#  7   release_year  7770 non-null   int64
#  8   rating        7770 non-null   object
#  9   duration      7770 non-null   object
#  10  listed_in     7770 non-null   object
#  11  description   7770 non-null   object
#  12  added_year    7770 non-null   int64
#  13  added_month   7770 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 910.5+ KB

# %% [markdown]
# # ANALYSIS

# %%
df['cast']
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7782    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                              Nasty C
# 7785                           Adriano Zumbo, Rachel Khoo
# 7786                                              Unknown
# Name: cast, Length: 7770, dtype: object

# %%
df['cast'].value_counts()
# Out:
# cast
# Unknown                                                                                                                                                                       718
# David Attenborough                                                                                                                                                             18
# Samuel West                                                                                                                                                                    10
# Jeff Dunham                                                                                                                                                                     7
# Michela Luci, Jamie Watson, Eric Peterson, Anna Claire Bartlam, Nicolas Aqui, Cory Doran, Julie Lemieux, Derek McGrath                                                          6
# ...

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0               Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.groupby('country')['title'].count()
# Out:
# country
# Argentina                                              50
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        1
# Argentina, Chile, Peru                                  1
# Argentina, France                                       1
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 5
# West Germany                                            1
# Zimbabwe                                                1
# Name: title, Length: 681, dtype: int64

# %%
df.groupby('release_year')['title'].count().sort_values(ascending=False).head(5)
# Out:
# release_year
# 2018    1120
# 2017    1010
# 2019     996
# 2016     881
# 2020     868
# Name: title, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df,x='rating')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
df.to_csv("netflic.csv")
